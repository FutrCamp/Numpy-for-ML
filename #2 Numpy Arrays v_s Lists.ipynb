# %% [markdown]
# ### **Arrays**
# An array is a data structure that stores values of same data type. In Python, this is the main difference between arrays and lists. While python lists can contain values corresponding to different data types, arrays in python can only contain values corresponding to same data type

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# ### Always first import Numpy

# %%
import numpy as np

# %% [markdown]
# ### **First creating example list and array**

# %%
L = [1,2,3]
A = np.array([1,2,3])

# %% [markdown]
# ### Printing each element using Loops

# %%
for i in L:
  print(i)
# Out:
# 1
# 2
# 3

# %%
for i in A:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### **Appending**

# %%
L.append(4)
print(L)
# Out:
# [1, 2, 3, 4]

# %%
A.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a17c4d6940c3> in <module>()
# ----> 1 A.append(4)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %% [markdown]
# ### **Broadcasting**
# The term broadcasting refers to the ability of NumPy to treat arrays of different shapes during arithmetic operations. Arithmetic operations on arrays are usually done on corresponding elements. If two arrays are of exactly the same shape, then these operations are smoothly performed.

# %% [markdown]
# ![NumPy-Broadcasting.jpg](data:image/jpeg;base64,...)

# %%
L + [5]
# Out:
# [1, 2, 3, 4, 5]

# %%
A + np.array([4])
# Out:
# array([5, 6, 7])

# %% [markdown]
# ### **Adding Vectors**

# %%
A + np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
A + np.array([4,5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2a83055a136d> in <module>()
# ----> 1 A + np.array([4,5])
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %% [markdown]
# ### **Miscellaneous stuff**

# %%
L*2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
L + L
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
A*2
# Out:
# array([2, 4, 6])

# %%
L2 = []
for i in L:
  L2.append(i + 3)
print(L2)
# Out:
# [4, 5, 6, 7]

# %%
L2 = [ i +3 for i in L]
print(L2)
# Out:
# [4, 5, 6, 7]

# %%
L**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5065f2c40dbd> in <module>()
# ----> 1 L**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
A**2
# Out:
# array([1, 4, 9])

# %%
L2=[]
for i in L:
  L2.append(i**2)
print(L2)
# Out:
# [1, 4, 9, 16]

# %%
np.sqrt(A)
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
np.log(A)
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
np.exp(A)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])
