# %% [markdown]
# # Resources
# - [# 1 Why Use Numpy ?](https://insights.dice.com/2016/09/01/5-reasons-know-numpy/#:~:text=NumPy%20is%20written%20in%20C,always%20going%20to%20be%20faster.&text=Python%20loops%20are%20slower%20than%20C%20loops.)
# - [# 2 Why use Numpy ?](https://medium.com/swlh/why-use-numpy-d06c573fbcda)
#
# - [# 3 Speed Test](https://towardsdatascience.com/how-fast-numpy-really-is-e9111df44347)
